# %%
import pandas as pd

# %% [markdown]
# ## Generating the Synthetic data

# %%
expense_categories = {
    "Groceries & Essentials": [
        "Bought rice", "Milk and bread", "Vegetables", "BigBasket order", "Kirana shop", 
        "Monthly ration", "Cooking oil", "Daily groceries", "Eggs and butter", "Fruit market",
        "Grocery store", "Sugar and flour", "Green veggies", "Meat and fish", "Organic food",
        "Dairy products", "Soap and detergent", "Stationery", "Toiletries", "Household items"
    ],
    "Food & Dining": [
        "McDonalds burger", "Zomato samosa", "Starbucks coffee", "Pizza Hut", "Dominos order",
        "KFC chicken", "Subway sandwich", "Street food", "Fine dining", "Cafe latte",
        "Bakery items", "Ice cream", "Snacks", "Pani puri", "Biryani order",
        "Dinner with friends", "Lunch at office canteen", "Midnight snacks", "Swiggy delivery", "Chai tapri"
    ],
    "Transportation": [
        "Uber ride", "Ola cab", "Petrol pump", "Metro ticket", "Flight booking",
        "Auto fare", "Bus ticket", "Train travel", "Bike fuel", "Taxi stand",
        "Parking fees", "Car wash", "Toll tax", "Highway toll", "Cab pooling",
        "Flight seat upgrade", "Airport taxi", "Car rental", "Scooter repair", "EV charging"
    ],
    "Housing & Utilities": [
        "Paid rent", "Electricity bill", "Water bill", "Internet recharge", "Cooking gas",
        "House cleaning", "Maintenance charges", "Security fees", "Cable TV bill", "Home insurance",
        "Society charges", "House repairs", "Plumber fees", "Electrician charges", "New fan purchase",
        "Solar bill", "Gas pipeline", "Property tax", "AC servicing", "Painting walls"
    ],
    "Shopping & Lifestyle": [
        "Amazon order", "Flipkart shoes", "Bought clothes", "New phone", "Furniture",
        "Myntra order", "Shopping mall", "Jeans and t-shirt", "Headphones", "Smartwatch",
        "Beauty products", "Jewellery", "Cosmetics", "Home decor", "Kitchen appliances",
        "Handbag", "Perfume", "Online fashion store", "Electronics shop", "Sports shoes"
    ],
    "Healthcare & Fitness": [
        "Pharmacy bill", "Doctor visit", "Gym subscription", "Protein powder", "Yoga class",
        "Hospital consultation", "Medicines", "Health checkup", "Fitness app", "Running shoes",
        "Dental treatment", "Eye checkup", "Physiotherapy", "Health supplements", "Dietician",
        "Vitamins", "Surgery fees", "Medical test", "Lab report", "Hospital admission"
    ],
    "Entertainment & Leisure": [
        "Netflix subscription", "Movie ticket", "Bought PS5 game", "Spotify premium", "Concert",
        "Amusement park", "Board games", "Standup comedy", "Online gaming", "Music album",
        "Karaoke night", "Bowling", "Cricket match ticket", "Football match", "Dance class",
        "Pool party", "Night club", "Arcade games", "OTT subscription", "Festival ticket"
    ],
    "Travel & Vacation": [
        "Hotel booking", "Airbnb stay", "Train tickets", "Goa trip", "Flight to Delhi",
        "Taxi in another city", "Holiday package", "Travel insurance", "Guided tour", "Luggage shopping",
        "International flight", "Resort booking", "Visa fees", "Passport renewal", "Car rental abroad",
        "Trekking trip", "Camping gear", "Beach vacation", "Cruise booking", "Mountain stay"
    ],
    "Education & Learning": [
        "course", "Udemy course", "Python book", "College fee", "Coaching class", "E-learning app",
        "Stationery", "Exam fees", "Library subscription", "School tuition", "Notebook purchase",
        "Pen and pencils", "Data science course", "Skillshare", "Workshop fee", "Training session",
        "Online certification", "Language course", "Coding bootcamp", "Educational magazine", "MBA fees"
    ],
    "Finance & Investments": [
        "Bought stocks", "Invested in crypto", "Mutual fund SIP", "Bank transfer", "FD deposit",
        "Insurance premium", "Pension contribution", "Equity trading", "ETF investment", "Real estate investment",
        "Bond purchase", "Savings account transfer", "Gold purchase", "Crypto exchange", "Wealth management",
        "Stockbroker fee", "Dividend reinvestment", "Demat account charges", "Loan to friend", "Crowdfunding"
    ],
    "Debt & Loans": [
        "Credit card bill", "Personal loan EMI", "Car loan repayment", "Mortgage payment", "EMI deduction",
        "Student loan", "Overdraft charges", "Business loan", "Loan interest", "Pay later repayment",
        "Microfinance loan", "Credit EMI", "Housing loan", "Loan penalty", "Credit settlement",
        "Bank loan", "Installment deduction", "Outstanding EMI", "Debt repayment", "Credit renewal"
    ],
    "Miscellaneous / Other": [
        "Gift for friend", "Charity donation", "Random purchase", "Festival shopping", "Birthday cake",
        "Anniversary gift", "Party expenses", "Wedding contribution", "Child toy", "Donation drive",
        "Pet care", "Flower bouquet", "Event contribution", "Unexpected expense", "Holiday gift",
        "Fun fair ticket", "Personal expense", "Hobby material", "DIY tools", "Festival sweets"
    ]
}
item_amounts = {
    # Groceries
    "Bought rice": (200, 1000),
    "Milk and bread": (50, 150),
    "Vegetables": (100, 500),
    "Fruit market": (100, 800),
    "Cooking oil": (150, 500),
    "Monthly ration": (1000, 4000),
    "Meat and fish": (300, 1500),

    # Food & Dining
    "Chai tapri": (10, 30),
    "Street food": (20, 150),
    "Starbucks coffee": (200, 500),
    "Fine dining": (800, 3000),
    "McDonalds burger": (100, 300),
    "Pizza Hut": (200, 800),
    "Dinner with friends": (500, 2000),

    # Transportation
    "Uber ride": (100, 500),
    "Ola cab": (100, 500),
    "Petrol pump": (500, 3000),
    "Metro ticket": (20, 100),
    "Flight booking": (3000, 20000),

    # Housing
    "Paid rent": (5000, 30000),
    "Electricity bill": (500, 3000),
    "Water bill": (200, 1000),
    "Internet recharge": (500, 1500),
    "Cooking gas": (600, 1500),
    "House repairs": (500, 10000),

    # Shopping
    "New phone": (8000, 60000),
    "Furniture": (5000, 50000),
    "Smartwatch": (2000, 15000),
    "Beauty products": (500, 5000),
    "Jeans and t-shirt": (800, 3000),

    # Healthcare
    "Pharmacy bill": (100, 2000),
    "Doctor visit": (500, 3000),
    "Hospital admission": (10000, 100000),
    "Gym subscription": (500, 5000),
    "Protein powder": (1000, 5000),

    # Entertainment
    "Netflix subscription": (200, 800),
    "Movie ticket": (150, 500),
    "Concert": (1000, 5000),
    "Night club": (1000, 7000),

    # Travel
    "Train tickets": (300, 2000),
    "Flight to Delhi": (4000, 15000),
    "International flight": (20000, 100000),
    "Hotel booking": (2000, 20000),
    "Holiday package": (10000, 50000),

    # Education
    "Udemy course": (300, 2000),
    "College fee": (20000, 150000),
    "Exam fees": (1000, 5000),
    "Notebook purchase": (50, 500),

    # Finance
    "Bought stocks": (1000, 100000),
    "Invested in crypto": (500, 50000),
    "FD deposit": (5000, 200000),
    "Insurance premium": (2000, 50000),

    # Loans
    "Credit card bill": (500, 50000),
    "Mortgage payment": (10000, 200000),
    "Personal loan EMI": (5000, 50000),

    # Miscellaneous
    "Birthday cake": (300, 1500),
    "Gift for friend": (500, 5000),
    "Charity donation": (200, 20000),
}


category_amounts = {
    "Groceries & Essentials": (100, 2000),
    "Food & Dining": (50, 1000),
    "Transportation": (100, 3000),
    "Housing & Utilities": (500, 10000),
    "Shopping & Lifestyle": (200, 10000),
    "Healthcare & Fitness": (100, 15000),
    "Entertainment & Leisure": (100, 5000),
    "Travel & Vacation": (500, 50000),
    "Education & Learning": (200, 100000),
    "Finance & Investments": (500, 200000),
    "Debt & Loans": (500, 100000),
    "Miscellaneous / Other": (50, 5000)
}

# %%
import random
import pandas as pd
import numpy

import faker 
from datetime import datetime, timedelta


fake = faker.Faker()

def generate_transaction(num_records=10000):

    data = []
    start_date = datetime.now() - timedelta(days=730)

    for i in range(1, num_records+1):

        #category = random.choice(list(expense_categories.keys())) 
        #Let's try weightage category
        weighted_categories = random.choices(
            list(expense_categories.keys()), 
            weights=[20,15,10,10,10,7,7,5,5,5,3,3],  
            k=1
        )[0]
        
        note = random.choice(expense_categories[weighted_categories])
        if note in item_amounts:
            low, high = item_amounts[note]
        else:       
            low, high = category_amounts[weighted_categories]
        amount = round(random.uniform(low, high), 2)
        days_offset = random.randint(0, 730)
        date = start_date + timedelta(days=days_offset)

        data.append([
            i, 
            date.strftime("%Y-%m-%d"),
            amount,
            note,
            weighted_categories
        ])

    df = pd.DataFrame(data, columns=["transaction_id", "date", "amount", "note", "category"])
    return df

df = generate_transaction(10000)
df.to_csv("transactions.csv", index=False)
print("Done")
# Out:
# Done

# %%
gen_df= pd.read_csv("/Users/abhinavyadav/Projects/SpendSense/Data/transactions.csv")

# %%
gen_df.head()
# Out:
#    transaction_id        date   amount              note  \
# 0               1  2025-03-15   110.95    Milk and bread
# 1               2  2024-09-01  8062.42  Dental treatment
# 2               3  2024-05-17  7212.25      Myntra order
# 3               4  2025-02-22   885.99      Organic food
# 4               5  2024-05-27   960.13     Meat and fish
#
#                  category
# 0  Groceries & Essentials
# 1    Healthcare & Fitness
# 2    Shopping & Lifestyle
# 3  Groceries & Essentials
# 4  Groceries & Essentials

# %%
gen_df = gen_df.set_index('transaction_id')
gen_df.head()
# Out:
#                       date   amount              note                category
# transaction_id
# 1               2025-03-15   110.95    Milk and bread  Groceries & Essentials
# 2               2024-09-01  8062.42  Dental treatment    Healthcare & Fitness
# 3               2024-05-17  7212.25      Myntra order    Shopping & Lifestyle
# 4               2025-02-22   885.99      Organic food  Groceries & Essentials
# 5               2024-05-27   960.13     Meat and fish  Groceries & Essentials

# %%
gen_df.sample(10)
# Out:
#                       date     amount                   note  \
# transaction_id
# 5929            2024-05-15    5864.82             Home decor
# 2151            2025-07-18     838.16          Birthday cake
# 9735            2025-08-20      89.47           Metro ticket
# 1637            2024-06-13     497.47            Cooking oil
# 6801            2024-12-22   36866.03       Credit card bill
# 3517            2024-09-13  161895.70  Dividend reinvestment
# 971             2023-11-24     847.49         Amusement park
# 9540            2025-04-06   82341.22  Dividend reinvestment
# 3668            2024-04-18    1799.22          Pharmacy bill
# 7909            2023-10-27  119759.79  Dividend reinvestment
#
#                                category
# transaction_id
# 5929               Shopping & Lifestyle
# 2151              Miscellaneous / Other
# 9735                     Transportation
# 1637             Groceries & Essentials
# 6801                       Debt & Loans
# 3517              Finance & Investments
# 971             Entertainment & Leisure
# 9540              Finance & Investments
# 3668               Healthcare & Fitness
# 7909              Finance & Investments

# %%
import matplotlib.pyplot as plt

category_totals = gen_df.groupby('category').size()
plt.figure(figsize=(10, 8))
plt.pie(category_totals.values, labels=category_totals.index, autopct='%1.1f%%')
plt.title('Spending Distribution by Category')
plt.show()

# %%
gen_df = gen_df[~gen_df['category'].isin(["Finance & Investments", "Debt & Loans"])]

# %%
gen_df
# Out:
#                       date   amount              note                category
# transaction_id
# 1               2025-03-15   110.95    Milk and bread  Groceries & Essentials
# 2               2024-09-01  8062.42  Dental treatment    Healthcare & Fitness
# 3               2024-05-17  7212.25      Myntra order    Shopping & Lifestyle
# 4               2025-02-22   885.99      Organic food  Groceries & Essentials
# 5               2024-05-27   960.13     Meat and fish  Groceries & Essentials
# ...                    ...      ...               ...                     ...
# 9996            2025-02-05  1378.58        Bus ticket          Transportation
# 9997            2025-03-02  1887.35      Myntra order    Shopping & Lifestyle
# 9998            2024-08-16  1797.98      Organic food  Groceries & Essentials
# 9999            2023-10-25    19.63        Chai tapri           Food & Dining
# 10000           2024-05-11  2272.64      Parking fees          Transportation
#
# [9168 rows x 4 columns]

# %% [markdown]
# - Based on number of transaction

# %%
import matplotlib.pyplot as plt

category_totals = gen_df.groupby('category').size()
plt.figure(figsize=(10, 8))
plt.pie(category_totals.values, labels=category_totals.index, autopct='%1.1f%%')
plt.title('Number of Transaction Distribution by Category')
plt.show()

# %% [markdown]
# - Based on money spend

# %%
import matplotlib.pyplot as plt

category_totals = gen_df.groupby('category')['amount'].sum()
plt.figure(figsize=(10, 8))
plt.pie(category_totals.values, labels=category_totals.index, autopct='%1.1f%%')
plt.title('Spending Distribution by Category')
plt.show()

# %%
gen_df[gen_df['category'].isin(['Food & Dining'])].sample(20)
# Out:
#                       date   amount                     note       category
# transaction_id
# 4268            2024-01-01   160.31          Subway sandwich  Food & Dining
# 6839            2025-08-06  1233.22      Dinner with friends  Food & Dining
# 5639            2025-07-28   835.71             Bakery items  Food & Dining
# 6387            2025-02-23   266.01             Bakery items  Food & Dining
# 6109            2024-10-15   999.37                Ice cream  Food & Dining
# 7374            2023-10-12    11.34               Chai tapri  Food & Dining
# 4517            2023-09-09   113.50              Street food  Food & Dining
# 3805            2025-04-09   712.10  Lunch at office canteen  Food & Dining
# 552             2025-06-15   743.18  Lunch at office canteen  Food & Dining
# 4646            2023-09-02   806.06            Dominos order  Food & Dining
# 2909            2023-12-29   552.25                Pizza Hut  Food & Dining
# 4809            2025-02-24   197.46             Bakery items  Food & Dining
# 173             2024-02-17   394.69          Swiggy delivery  Food & Dining
# 923             2023-12-29   340.05  Lunch at office canteen  Food & Dining
# 8815            2024-08-07   484.91            Zomato samosa  Food & Dining
# 8948            2024-12-15   284.83         McDonalds burger  Food & Dining
# 2025            2025-04-17  1014.59      Dinner with friends  Food & Dining
# 8166            2025-07-18   139.30          Subway sandwich  Food & Dining
# 2705            2024-11-21    90.21          Subway sandwich  Food & Dining
# 9869            2025-02-07   292.06         McDonalds burger  Food & Dining

# %%
gen_df[gen_df['category'].isin(["Groceries & Essentials"])]
# Out:
#                       date   amount            note                category
# transaction_id
# 1               2025-03-15   110.95  Milk and bread  Groceries & Essentials
# 4               2025-02-22   885.99    Organic food  Groceries & Essentials
# 5               2024-05-27   960.13   Meat and fish  Groceries & Essentials
# 18              2023-09-14  1332.22   Meat and fish  Groceries & Essentials
# 19              2024-07-14   433.57     Kirana shop  Groceries & Essentials
# ...                    ...      ...             ...                     ...
# 9987            2024-06-28   426.32      Vegetables  Groceries & Essentials
# 9988            2023-12-20   634.69   Green veggies  Groceries & Essentials
# 9989            2025-03-20  1645.46    Organic food  Groceries & Essentials
# 9992            2024-02-24   798.26   Green veggies  Groceries & Essentials
# 9998            2024-08-16  1797.98    Organic food  Groceries & Essentials
#
# [1959 rows x 4 columns]

# %%
gen_df[gen_df['note'].isin(['Snacks'])]
# Out:
#                       date   amount    note                category
# transaction_id
# 1               2025-03-15   110.95  Snacks  Groceries & Essentials
# 2               2024-09-01  8062.42  Snacks    Healthcare & Fitness
# 3               2024-05-17  7212.25  Snacks    Shopping & Lifestyle
# 4               2025-02-22   885.99  Snacks  Groceries & Essentials
# 5               2024-05-27   960.13  Snacks  Groceries & Essentials
# ...                    ...      ...     ...                     ...
# 9996            2025-02-05  1378.58  Snacks          Transportation
# 9997            2025-03-02  1887.35  Snacks    Shopping & Lifestyle
# 9998            2024-08-16  1797.98  Snacks  Groceries & Essentials
# 9999            2023-10-25    19.63  Snacks           Food & Dining
# 10000           2024-05-11  2272.64  Snacks          Transportation
#
# [9168 rows x 4 columns]

# %%
gen_df['note'].unique()
# Out:
# array(['Milk and bread', 'Dental treatment', 'Myntra order',
#        'Organic food', 'Meat and fish', 'Workshop fee', 'School tuition',
#        'Electricity bill', 'New phone', 'Maintenance charges',
#        'Train tickets', 'Cable TV bill', 'Snacks', 'Highway toll',
#        'Bike fuel', 'Kirana shop', 'Spotify premium', 'Bowling',
#        'Board games', 'Airbnb stay', 'Eggs and butter', 'Vitamins',
#        'Dairy products', 'Property tax', 'Dinner with friends',
#        'Home insurance', 'Training session', 'Football match',
#        'Bought rice', 'House cleaning', 'Cafe latte', 'Toiletries',
#        'Wedding contribution', 'Flipkart shoes', 'BigBasket order',
#        'Medicines', 'Flight seat upgrade', 'Hobby material',
#        'Electronics shop', 'Online fashion store', 'Toll tax',
#        'Fine dining', 'Electrician charges', 'Taxi in another city',
#        'Solar bill', 'Personal expense', 'Soap and detergent',
#        'Doctor visit', 'Car wash', 'Amusement park', 'Charity donation',
#        'Luggage shopping', 'Car rental abroad', 'McDonalds burger',
#        'Vegetables', 'Lunch at office canteen', 'Beauty products',
#        'Dietician', 'Daily groceries', 'Bought PS5 game', 'Arcade games',
#        'Cooking oil', 'Zomato samosa', 'International flight',
#        'Beach vacation', 'Petrol pump', 'Metro ticket',
#        'Passport renewal', 'Airport taxi', 'Stationery', 'Cooking gas',
#        'Coaching class', 'Camping gear', 'Event contribution',
#        'Fruit market', 'Handbag', 'Green veggies', 'Furniture',
#        'Swiggy delivery', 'Kitchen appliances', 'Grocery store',
#        'Bakery items', 'Auto fare', 'Health checkup', 'Dance class',
#        'Medical test', 'Plumber fees', 'Cricket match ticket',
#        'Monthly ration', 'Car rental', 'Taxi stand', 'Biryani order',
#        'Shopping mall', 'Hospital consultation', 'Movie ticket',
#        'Headphones', 'Karaoke night', 'Chai tapri', 'Surgery fees',
#        'Ice cream', 'Cosmetics', 'Lab report', 'Netflix subscription',
#        'Concert', 'Anniversary gift', 'New fan purchase', 'AC servicing',
#        'Fun fair ticket', 'Train travel', 'KFC chicken', 'Resort booking',
#        'Street food', 'House repairs', 'Perfume', 'Uber ride',
#        'OTT subscription', 'Guided tour', 'Household items', 'Pool party',
#        'College fee', 'Educational magazine', 'Sugar and flour',
#        'Subway sandwich', 'Data science course', 'Running shoes',
#        'Painting walls', 'Sports shoes', 'Festival shopping',
#        'Pharmacy bill', 'Child toy', 'Eye checkup', 'Health supplements',
#        'DIY tools', 'Standup comedy', 'Music album', 'Home decor',
#        'Party expenses', 'Dominos order', 'Notebook purchase',
#        'Night club', 'Festival sweets', 'Trekking trip', 'Ola cab',
#        'Holiday package', 'Jeans and t-shirt', 'Cruise booking',
#        'Society charges', 'Physiotherapy', 'Parking fees', 'Paid rent',
#        'Scooter repair', 'Bought clothes', 'Coding bootcamp',
#        'Bus ticket', 'Yoga class', 'Midnight snacks', 'Flight to Delhi',
#        'Hospital admission', 'Festival ticket', 'Birthday cake',
#        'Gas pipeline', 'Pani puri', 'Jewellery', 'Water bill',
#        'Hotel booking', 'course', 'E-learning app', 'Cab pooling',
#        'Gym subscription', 'Gift for friend', 'Internet recharge',
#        'Security fees', 'Mountain stay', 'Random purchase',
#        'Online gaming', 'Donation drive', 'Protein powder',
#        'Travel insurance', 'EV charging', 'Skillshare', 'Udemy course',
#        'Pet care', 'Pizza Hut', 'Python book', 'Exam fees',
#        'Language course', 'Fitness app', 'Starbucks coffee', 'Visa fees',
#        'Online certification', 'Smartwatch', 'Holiday gift', 'Goa trip',
#        'Pen and pencils', 'Amazon order', 'Flight booking',
#        'Flower bouquet', 'MBA fees', 'Library subscription',
#        'Unexpected expense'], dtype=object)

# %%
gen_df['note'].value_counts().head(20)
# Out:
# note
# Kirana shop           119
# Green veggies         114
# BigBasket order       111
# Biryani order         110
# Household items       109
# Cooking oil           109
# Stationery            108
# Bought rice           103
# Sugar and flour       102
# Meat and fish         101
# Soap and detergent     98
# Milk and bread         98
# Dairy products         98
# Eggs and butter        97
# Grocery store          96
# Organic food           94
# Fruit market           90
# Daily groceries        90
# Toiletries             87
# Monthly ration         87
# Name: count, dtype: int64
